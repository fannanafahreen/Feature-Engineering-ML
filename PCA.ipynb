# %% [markdown]
# # Converting images into pixel

# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

# %%
before_image = cv2.imread('before image.png',cv2.IMREAD_GRAYSCALE)
before_image
# Out:
# array([[ 43,  43,  43, ..., 255, 255, 255],
#        [ 43,  43,  43, ..., 255, 255, 255],
#        [ 43,  43,  43, ..., 255, 255, 255],
#        ...,
#        [ 43,  43,  43, ..., 255, 255, 255],
#        [ 43,  43,  43, ..., 255, 255, 255],
#        [ 43,  43,  43, ..., 255, 255, 255]], dtype=uint8)

# %%
before_image.shape
# Out:
# (518, 433)

# %%
sns.heatmap(before_image, cmap='gray')
# Out:
# <Axes: >

# %%
plt.matshow(before_image, cmap='gray')

# %%
img_resize= cv2.resize(before_image,(28,28)) #1 image needs lakh of number which 
img_resize                                   # database can not have. Database only takes 28*28
# Out:
# array([[255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 247,   0,   0,   0,   0,   0,   0, 253, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 253,   0,   0,   0,   0,   0,   0,   0, 253, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 253,   0,   0,   0,   0,   0,   0,   0,   0, 253, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255,   1,   0,   0,   0,   0,   0,   0,   0,   0, 253, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#           2,   0,   0,   0,   0,   0,   0,   0,   0,   0, 253, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 165,
# ...

# %%
img_resize.shape
# Out:
# (28, 28)

# %%
sns.heatmap(img_resize,cmap='gray')
# Out:
# <Axes: >

# %%
 sns.heatmap(img_resize,cmap='coolwarm')
# Out:
# <Axes: >
